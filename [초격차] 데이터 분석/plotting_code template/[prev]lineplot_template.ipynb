# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_path = "/content/drive/MyDrive/Lecture Materials/FastCampus/B2C/[초격차] 한 번에 끝내는 데이터 분석/codebook/실습용 Raw Data 50종"

# %%
import pandas as pd
data = pd.read_csv(base_path + "/#01_HR_Data_8500_직원정보 데이터.csv")
data
# Out:
#       EmployeeNumber    Surname  ... AbsentHours BusinessUnit
# 0                  1  Gutierrez  ...   36.577306       Stores
# 1                  2   Hardwick  ...   30.165072       Stores
# 2                  3    Delgado  ...   83.807798       Stores
# 3                  4      Simon  ...   70.020165       Stores
# 4                  5   Delvalle  ...    0.000000       Stores
# ...              ...        ...  ...         ...          ...
# 8331            8332   Coniglio  ...   93.665111       Stores
# 8332            8333        Cox  ...    0.000000       Stores
# 8333            8334    Hawkins  ...  176.356940       Stores
# 8334            8335    Proctor  ...   60.321917       Stores
# 8335            8336     Salter  ...  112.023389       Stores
#
# [8336 rows x 13 columns]

# %%
data.describe()
# Out:
#        EmployeeNumber          Age  LengthService  AbsentHours
# count     8336.000000  8336.000000    8336.000000  8336.000000
# mean      4168.500000    42.007086       4.782910    61.283978
# std       2406.540255     9.939798       2.462990    49.038365
# min          1.000000     3.504743       0.012098     0.000000
# 25%       2084.750000    35.298748       3.575892    19.127590
# 50%       4168.500000    42.114924       4.600248    56.005808
# 75%       6252.250000    48.666943       5.623922    94.284692
# max       8336.000000    77.938003      43.735239   272.530123

# %%
x = input("lineplot의 x축이 되는 column을 입력하세요 : ")
y = input("lineplot의 y축이 되는 column을 입력하세요 : ")
hue = input("lineplot의 색상 구분의 기준이 되는 column을 입력하세요 : ")
# Out:
# lineplot의 x축이 되는 column을 입력하세요 : Age
# lineplot의 y축이 되는 column을 입력하세요 : AbsentHours
# lineplot의 색상 구분의 기준이 되는 column을 입력하세요 : Gender

# %%
import matplotlib.pyplot as plt
import seaborn as sns

X = data[x].sort_values()#.values
Y = data[y]#.sort_values().values
HUE = data[hue]#.values

plt.figure(figsize=(16, 16))
sns.lineplot(data=data, x=x, y=y, hue=hue)
#sns.lineplot(x=X, y=Y, hue=HUE)
