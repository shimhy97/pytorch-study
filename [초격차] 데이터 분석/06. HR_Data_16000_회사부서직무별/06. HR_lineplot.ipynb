# %%
# 구글드라이브에서 데이터를 사용하기 위해서 Mount를 하는 코드입니다.
# 구글 계정으로 로그인하여, 구글드라이브에 있는 실습용 데이터를 사용할 수 있게 인증하는 방식입니다.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 실습용 데이터셋이 있는 경로입니다. (*** 구글드라이브 내 경로 ***)
# 본인의 경로에 맞게 수정해서 사용하세요. (자세한 사용법은 함께 제공되는 튜토리얼 영상을 확인하세요)
base_path = "/content/drive/MyDrive/Colab Notebooks/[초격차] 데이터 분석/input"

# %%
# 정형 데이터를 불러오고 조작하기 위해 Pandas 라이브러리를 사용합니다.
import pandas as pd
# 지정한 경로에 있는 데이터를 불러옵니다. csv 파일이냐 xlsx 파일이냐에 따라 사용하는 함수가 다릅니다.
data = pd.read_csv(base_path + "/#06_HR_Data_16000_회사부서직무별.csv")
data
# Out:
#        Unnamed: 0   Age  ... YearsWithCurrManager  Employee Source
# 0               0  41.0  ...                  5.0         Referral
# 1               1  37.0  ...                  5.0         Referral
# 2               2  41.0  ...                  5.0         Referral
# 3               3  37.0  ...                  5.0         Referral
# 4               4  37.0  ...                  5.0         Referral
# ...           ...   ...  ...                  ...              ...
# 16213       16379  24.0  ...                  3.0  Company Website
# 16214       16380  37.0  ...                  3.0  Company Website
# 16215       16381  24.0  ...                  3.0  Company Website
# 16216       16382  24.0  ...                  3.0        GlassDoor
# 16217       16383  24.0  ...                  3.0  Company Website
#
# [16218 rows x 34 columns]

# %%
# 불러온 데이터셋에 대한 전반적인 정보를 확인하는 함수입니다.
# row수, column수, 결측치 수, column별 data type을 확인합니다.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16218 entries, 0 to 16217
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                16218 non-null  int64
#  1   Age                       16218 non-null  float64
#  2   Attrition                 16218 non-null  object
#  3   BusinessTravel            16218 non-null  object
#  4   DailyRate                 16218 non-null  float64
#  5   Department                16218 non-null  object
#  6   DistanceFromHome          16218 non-null  int64
#  7   Education                 16218 non-null  float64
#  8   EducationField            16218 non-null  object
#  9   Application ID            16218 non-null  int64
#  10  EnvironmentSatisfaction   16218 non-null  float64
#  11  Gender                    16218 non-null  object
#  12  HourlyRate                16218 non-null  float64
#  13  JobInvolvement            16218 non-null  float64
#  14  JobLevel                  16218 non-null  float64
#  15  JobRole                   16218 non-null  object
#  16  JobSatisfaction           16218 non-null  float64
#  17  MaritalStatus             16218 non-null  object
#  18  MonthlyIncome             16218 non-null  float64
#  19  MonthlyRate               16218 non-null  float64
#  20  NumCompaniesWorked        16218 non-null  float64
#  21  OverTime                  16218 non-null  object
#  22  PercentSalaryHike         16218 non-null  float64
#  23  PerformanceRating         16218 non-null  float64
#  24  RelationshipSatisfaction  16218 non-null  float64
#  25  StockOptionLevel          16218 non-null  float64
#  26  TotalWorkingYears         16218 non-null  float64
#  27  TrainingTimesLastYear     16218 non-null  float64
#  28  WorkLifeBalance           16218 non-null  float64
#  29  YearsAtCompany            16218 non-null  float64
#  30  YearsInCurrentRole        16218 non-null  float64
#  31  YearsSinceLastPromotion   16218 non-null  float64
#  32  YearsWithCurrManager      16218 non-null  float64
#  33  Employee Source           16218 non-null  object
# dtypes: float64(22), int64(3), object(9)
# memory usage: 4.2+ MB

# %%
# 데이터의 통계량을 확인합니다.
data.describe()
# Out:
#          Unnamed: 0  ...  YearsWithCurrManager
# count  16218.000000  ...          16218.000000
# mean    8204.735911  ...              4.150018
# std     4727.255005  ...              3.621532
# min        0.000000  ...              0.000000
# 25%     4113.250000  ...              2.000000
# 50%     8210.500000  ...              3.000000
# 75%    12296.750000  ...              7.000000
# max    16383.000000  ...             17.000000
#
# [8 rows x 25 columns]

# %%
# plotting을 위해 사용하는 parameter들을 사용자로부터 입력받습니다.

# x는 lineplot의 x축에 표현되는 feature를 의미합니다. data에 존재하는 column중에 x축에 표시하고 싶은 column의 이름을 입력하세요.
# x축 정보는 lineplot이 나뉘는 기준입니다.
x = input("lineplot의 x축이 되는 column을 입력하세요 : ")
# y는 lineplot의 y축에 표현되는 feature를 의미합니다. data에 존재하는 column중에 y축에 표시하고 싶은 column의 이름을 입력하세요.
# y축 정보는 lineplot에 들어가는 실제값입니다.
y = input("lineplot의 y축이 되는 column을 입력하세요 : ")
# hue는 lineplot에서 각 plot마다 색을 다르게 주는 기준이 되는 feature를 의미합니다. data에 존재하는 column중에 hue에 표시하고 싶은 column의 이름을 입력하세요.
# hue는 plot에서 색 정보를 통해서 구분되어 표현되는 column을 의미합니다.
hue = input("lineplot의 색상 구분의 기준이 되는 column을 입력하세요 : ")
# Out:
# lineplot의 x축이 되는 column을 입력하세요 : Education
# lineplot의 y축이 되는 column을 입력하세요 : DailyRate
# lineplot의 색상 구분의 기준이 되는 column을 입력하세요 : WorkLifeBalance

# %%
# 그래프를 출력할 때 필요한 설정을 해주는 matplotlib.pyplot을 불러옵니다.
import matplotlib.pyplot as plt
# lineplot을 그려주는 라이브러리인 seaborn을 불러옵니다.
import seaborn as sns

# 출력할 plot의 크기를 정해줍니다. 16 x 16의 크기로 지정합니다.
plt.figure(figsize=(16, 16))
# 위에서 입력받은 x, y, hue를 기준으로 lineplot을 그립니다.
sns.lineplot(data=data, x=x, y=y, hue=hue)
# plot을 출력합니다.
plt.show()
